# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.bottom'] = True

# %%
df = pd.read_csv('/content/drive/MyDrive/SusztakLabFiles/Explant_quantifications/ligandCorr.csv')
df["gene"] = df.Ligand
df.tail()
# Out:
#      Unnamed: 0 Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 873         873   XCL1  0.007898 -0.004700  0.010429  0.000715 -0.010772
# 874         874   XCL2  0.002213 -0.002070  0.015066 -0.003520 -0.006968
# 875         875   XCR1 -0.021201  0.019904 -0.002601  0.018267 -0.006374
# 876         876   XPR1 -0.062261  0.074292  0.369586 -0.109647 -0.109952
# 877         877   YARS  0.111429 -0.090807 -0.041198 -0.007477  0.012721
#
#           DCT    Tubule      Glom  PseudoTime  gene
# 873 -0.000049 -0.000031  0.000715   -0.013549  XCL1
# 874 -0.002678  0.003479 -0.003520   -0.007260  XCL2
# 875 -0.018512 -0.017764  0.018267    0.035442  XCR1
# 876 -0.073635  0.117317 -0.109647    0.031776  XPR1
# 877  0.041185  0.008996 -0.007477   -0.212531  YARS

# %%
agt_index = df[df['Ligand'] == "AGT"].index[0]
print(agt_index)
avp_index = df[df['Ligand'] == "AVP"].index[0]
ace2_index = df[df['Ligand'] == "ACE2"].index[0]

#plt.hist(df['PT'], bins=50, density=True)
plt.hist(df['PT'], bins=50, density = True)

# Annotate specific observations (replace with your actual indices)
plt.annotate("AGT", xy=(df['PT'][agt_index], 0.05), xytext=(5, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("AVP", xy=(df['PT'][avp_index], 0.05), xytext=(-25, 40), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("ACE2", xy=(df['PT'][ace2_index], 0.05), xytext=(-60, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

# Customize the plot (optional)
plt.title("PT Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()
# Out:
# 28

# %%
rspo_index = df[df['Ligand'] == "RSPO3"].index[0]
gdnf_index = df[df['Ligand'] == "GDNF"].index[0]
igf2_index = df[df['Ligand'] == "IGF2"].index[0]

plt.hist(df['Renew'], bins=50, density=True)

# Annotate specific observations (replace with your actual indices)

plt.annotate("RSPO3", xy=(df['Renew'][rspo_index], 0.05), xytext=(0, 50), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("GDNF", xy=(df['Renew'][gdnf_index], 0.05), xytext=(-20, 60), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("IGF2", xy=(df['Renew'][igf2_index], 0.05), xytext=(-25, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

# Customize the plot (optional)
plt.title("Renew Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
vegf_index = df[df['Ligand'] == "VEGFA"].index[0]
efnb2_index = df[df['Ligand'] == "EFNB2"].index[0]
fgf1_index = df[df['Ligand'] == "FGF1"].index[0]

plt.hist(df['Podocyte'], bins=50, density=True)

# Annotate specific observations (replace with your actual indices)

plt.annotate("VEGFA", xy=(df['Podocyte'][vegf_index], 0.05), xytext=(-25, 60), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("EFNB2", xy=(df['Podocyte'][efnb2_index], 0.05), xytext=(-20, 40), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("FGF1", xy=(df['Podocyte'][fgf1_index], 0.05), xytext=(-50, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

# Customize the plot (optional)
plt.title("Podocyte Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
gene1_index = df[df['Ligand'] == "FGF9"].index[0]
gene2_index = df[df['Ligand'] == "KNG1"].index[0]
gene3_index = df[df['Ligand'] == "EGF"].index[0]

plt.hist(df['LOH'], bins=50, density=True)

# Annotate specific observations (replace with your actual indices)

plt.annotate("FGF9", xy=(df['LOH'][gene1_index], 0.05), xytext=(-25, 60), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("KNG1", xy=(df['LOH'][gene2_index], 0.05), xytext=(0, 30), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("EGF", xy=(df['LOH'][gene3_index], 0.05), xytext=(0, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

# Customize the plot (optional)
plt.title("LOH Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
gene1_index = df[df['Ligand'] == "EFNA4"].index[0]
gene2_index = df[df['Ligand'] == "LGR5"].index[0]
gene3_index = df[df['Ligand'] == "ITGA2"].index[0]

plt.hist(df['DCT'], bins=50, density=True)

# Annotate specific observations (replace with your actual indices)

plt.annotate("EFNA4", xy=(df['DCT'][gene1_index], 0.05), xytext=(-25, 60), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("LRG5", xy=(df['DCT'][gene2_index], 0.05), xytext=(-60, 40), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)
plt.annotate("ITGA2", xy=(df['DCT'][gene3_index], 0.05), xytext=(-40, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

# Customize the plot (optional)
plt.title("DCT Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
# prompt: write dataframe to csv

df.to_csv('ligandCorr_updated.csv', index=False)

# %%
import pandas as pd
df2 = pd.read_csv('/content/drive/MyDrive/SusztakLabFiles/Explant_quantifications/ligandCorrUB.csv')  # Replace with your file path
merged_df = pd.merge(df, df2, on='Ligand')
print(merged_df.head())
merged_df.to_csv('/content/drive/MyDrive/SusztakLabFiles/Explant_quantifications/ligandCorrUB_merged.csv')
# Out:
#    Unnamed: 0_x Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 0             0   ACE2 -0.157377  0.141251  0.503422 -0.193547 -0.075269
# 1             1  ACKR1       NaN       NaN       NaN       NaN       NaN
# 2             2  ACKR2 -0.038337  0.031189 -0.011395 -0.079729  0.112494
# 3             3  ACKR3 -0.241737  0.221895 -0.116095  0.368391 -0.159354
# 4             4  ACKR4 -0.081680  0.073520 -0.011380  0.051735 -0.004946
#
#         DCT    Tubule      Glom  PseudoTime   gene  Unnamed: 0_y       CNT  \
# 0 -0.113056  0.196858 -0.193547    0.230658   ACE2             0  0.206016
# 1       NaN       NaN       NaN         NaN  ACKR1             1       NaN
# 2  0.027442  0.079629 -0.079729   -0.000488  ACKR2             2 -0.411217
# 3 -0.294658 -0.365210  0.368391    0.505840  ACKR3             3 -0.356040
# 4 -0.061390 -0.050760  0.051735    0.133139  ACKR4             4 -0.167917
#
#          IC  Urethelium
# 0  0.006817   -0.224571
# 1       NaN         NaN
# ...

# %%
# prompt: Can you sort the dataframe above to show the highest values for CNT

sorted_df = merged_df.sort_values('IC', ascending=False)
print(sorted_df)
# Out:
#      Unnamed: 0_x Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 473           473   IL18 -0.094102  0.102715 -0.188400  0.378329 -0.237698
# 785           785  TDGF1 -0.115177  0.096686 -0.007711 -0.121072  0.208748
# 662           662  NTRK1  0.082733 -0.093935 -0.015810 -0.047834  0.059787
# 79             79  C5AR2 -0.046672  0.036717 -0.010369 -0.016148  0.034764
# 559           559    KIT -0.178686  0.141211 -0.028975 -0.055335  0.100633
# ..            ...    ...       ...       ...       ...       ...       ...
# 747           747  RXFP4       NaN       NaN       NaN       NaN       NaN
# 749           749   SAA1       NaN       NaN       NaN       NaN       NaN
# 853           853  VEGFD       NaN       NaN       NaN       NaN       NaN
# 858           858   VSIR       NaN       NaN       NaN       NaN       NaN
# 871           871  WNT7A       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# prompt: can you add labels to the points that have the value of "Ligand" to be "SEMA4D"

import matplotlib.pyplot as plt

# Assuming you have already plotted your histogram as in your previous code.

# Find the index of the row where 'Ligand' is 'SEMA4D'
sema4d_index = df[df['Ligand'] == "SEMA4D"].index[0]

# Get the x and y coordinates for the point you want to label
x_coord = df['PT'][sema4d_index]  # Replace 'PT' with the column you are plotting on the x-axis
y_coord = 0.05  # Adjust this based on the y-axis value where you want to place the label


# Annotate the point with "SEMA4D"

# Customize the plot (optional)
plt.title("PT Absorption Probability", fontsize=20)
plt.xlabel("Correlation")
plt.ylabel("Density")

# Show the plot
plt.show()

# %%
# prompt: can you make a scatter plot of CNT and DCT from the plot above?

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(merged_df['CNT'], merged_df['DCT'], alpha=0.5)
plt.xlabel('CNT')
plt.ylabel('DCT')
plt.title('Scatter Plot of CNT vs DCT')

sema4d_index = df[df['Ligand'] == "SEMA4D"].index[0]
plt.annotate("SEMA4D", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(5, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

sema4d_index = df[df['Ligand'] == "FGF2"].index[0]
plt.annotate("FGF2", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(5, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

sema4d_index = df[df['Ligand'] == "EPHB3"].index[0]
plt.annotate("EPHB3", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(5, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

plt.grid(False)
plt.show()

# %%
# prompt: can you move the SEMA4D annotation text in the plot above?

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(merged_df['CNT'], merged_df['DCT'], alpha=0.5)
plt.xlabel('CNT')
plt.ylabel('DCT')
plt.title('Scatter Plot of CNT vs DCT')

sema4d_index = df[df['Ligand'] == "SEMA4D"].index[0]
plt.annotate("SEMA4D", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(-150,10), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

sema4d_index = df[df['Ligand'] == "FGF2"].index[0]
plt.annotate("FGF2", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(-50, 20), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

sema4d_index = df[df['Ligand'] == "EPHA4"].index[0]
plt.annotate("EPHA4", xy=(merged_df['CNT'][sema4d_index], merged_df['DCT'][sema4d_index]), xytext=(10, 30), textcoords="offset points", arrowprops=dict(arrowstyle="-"), fontsize=24)

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(df['DCT'], df['LOH'])
plt.xlabel('DCT correlation')
plt.ylabel('LOH correlation')
plt.title('Ligand Correlation')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0 Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 0           0   ACE2 -0.156608  0.138575  0.502036 -0.190563 -0.075219
# 1           1  ACKR1       NaN       NaN       NaN       NaN       NaN
# 2           2  ACKR2 -0.039690  0.019063 -0.012939 -0.082934  0.110940
# 3           3  ACKR3 -0.241365  0.213143 -0.116179  0.361410 -0.158972
# 4           4  ACKR4 -0.081625  0.070080 -0.011609  0.050065 -0.004804
#
#         DCT    Tubule      Glom  PseudoTime
# 0 -0.110381  0.195595 -0.190563    0.230290
# 1       NaN       NaN       NaN         NaN
# 2  0.029375  0.079096 -0.082934   -0.001911
# 3 -0.285596 -0.361434  0.361410    0.503748
# 4 -0.059150 -0.049921  0.050065    0.132450

# %%
df2 = pd.read_csv('/content/drive/MyDrive/SusztakLabFiles/Explant_quantifications/NephroLineageDrivers_specification.csv')
df2 = df2.rename(columns={'Unnamed: 0': 'gene'})
df2.head()
# Out:
#       gene  DCT_corr  DCT_pval  DCT_qval  DCT_ci_low  DCT_ci_high  LOH_corr  \
# 0    WFDC2  0.468974       0.0       0.0    0.461405     0.476476  0.302124
# 1   LIMCH1  0.441871       0.0       0.0    0.434064     0.449612  0.234893
# 2  TMEM52B  0.428016       0.0       0.0    0.420093     0.435874  0.114259
# 3      MAL  0.398556       0.0       0.0    0.390399     0.406650  0.516818
# 4    MECOM  0.381960       0.0       0.0    0.373679     0.390180  0.436592
#
#         LOH_pval       LOH_qval  LOH_ci_low  ...   PT_corr       PT_pval  \
# 0   0.000000e+00   0.000000e+00    0.293321  ... -0.090193  3.346077e-75
# 1   0.000000e+00   0.000000e+00    0.225745  ... -0.069015  1.097882e-44
# 2  6.457181e-120  1.497720e-118    0.104715  ... -0.062715  3.497947e-37
# 3   0.000000e+00   0.000000e+00    0.509703  ... -0.078685  1.329095e-57
# 4   0.000000e+00   0.000000e+00    0.428740  ... -0.091653  1.310086e-77
#
# ...

# %%
# prompt: merge df and df2 by gene

import pandas as pd
merged_df = pd.merge(df, df2, on='gene', how='outer')
merged_df.head()
# Out:
#    Unnamed: 0 Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 0         0.0   ACE2 -0.156608  0.138575  0.502036 -0.190563 -0.075219
# 1         1.0  ACKR1       NaN       NaN       NaN       NaN       NaN
# 2         2.0  ACKR2 -0.039690  0.019063 -0.012939 -0.082934  0.110940
# 3         3.0  ACKR3 -0.241365  0.213143 -0.116179  0.361410 -0.158972
# 4         4.0  ACKR4 -0.081625  0.070080 -0.011609  0.050065 -0.004804
#
#         DCT    Tubule      Glom  ...   PT_corr       PT_pval       PT_qval  \
# 0 -0.110381  0.195595 -0.190563  ...  0.348859  0.000000e+00  0.000000e+00
# 1       NaN       NaN       NaN  ...       NaN           NaN           NaN
# 2  0.029375  0.079096 -0.082934  ...       NaN           NaN           NaN
# 3 -0.285596 -0.361434  0.361410  ... -0.060311  1.650829e-34  1.561245e-33
# 4 -0.059150 -0.049921  0.050065  ...       NaN           NaN           NaN
#
#    PT_ci_low  PT_ci_high  Podocyte_corr  Podocyte_pval  Podocyte_qval  \
# ...

# %%
# prompt: can you sort merged_df by PT in descending order

merged_df_sorted = merged_df.sort_values('PT', ascending=False)
merged_df_sorted.head(20)
# Out:
#      Unnamed: 0   Ligand     Renew      Diff        PT  Podocyte       LOH  \
# 707       707.0     PRLR -0.158680  0.137066  0.541570 -0.251788 -0.047473
# 28         28.0      AGT -0.135093  0.118992  0.525203 -0.217769 -0.074422
# 823       823.0  TNFSF10 -0.154814  0.139994  0.523845 -0.222379 -0.073855
# 52         52.0      AVP -0.141641  0.125530  0.519642 -0.207818 -0.083184
# 20         20.0     ADM2 -0.114682  0.103908  0.503342 -0.204688 -0.081829
# 0           0.0     ACE2 -0.156608  0.138575  0.502036 -0.190563 -0.075219
# 303       303.0    ERBB3 -0.207505  0.181555  0.501584 -0.216914 -0.065896
# 307       307.0      F10 -0.109979  0.082623  0.483986 -0.270345  0.019875
# 561       561.0       KL -0.198695  0.168346  0.483575 -0.239280 -0.026488
# 334       334.0    FGFR3 -0.192653  0.169027  0.478832 -0.335207  0.085195
# 672       672.0      OXT -0.113651  0.100219  0.473543 -0.198585 -0.065214
# ...

# %%
# prompt: can you make a scatter plot of PT and PT_corr for the merged dataframe, and label the point ACE2 and AVP

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['PT'], merged_df['PT_corr'])
plt.xlabel('PT')
plt.ylabel('PT_corr')
plt.title('Scatter Plot of PT vs PT_corr')

# Annotate ACE2 and AVP points
ace2_row = merged_df[merged_df['gene'] == 'FGF9']

plt.annotate('GOI', (ace2_row['PT'].iloc[0], ace2_row['PT_corr'].iloc[0])) # Access the specific 'PT' and 'PT_corr' values for ACE2

plt.show()

# %%
# prompt: can you return the highest values of PT that also have a non NaN value for PT_corr

# Filter out rows with NaN values in 'PT_corr'
valid_rows = merged_df[merged_df['PT_corr'].notna()]

# Sort the filtered DataFrame by 'PT' in descending order
sorted_df = valid_rows.sort_values('PT', ascending=False)

# Get the top rows with the highest 'PT' values
highest_pt_with_corr = sorted_df[['gene', 'PT', 'PT_corr']].head(10)  # Adjust the number of top rows as needed

print(highest_pt_with_corr)
# Out:
#         gene        PT   PT_corr
# 707     PRLR  0.541570  0.431298
# 823  TNFSF10  0.523845  0.437334
# 0       ACE2  0.502036  0.348859
# 303    ERBB3  0.501584  0.257999
# 307      F10  0.483986  0.219292
# 561       KL  0.483575  0.309921
# 334    FGFR3  0.478832  0.242626
# 621     MST1  0.470395  0.108411
# 262     DPP4  0.459846  0.275704
# 710    PROS1  0.445039  0.120881

# %%
avp_row['PT'].iloc[0], avp_row['PT_corr'].iloc[0]
# Out:
# (0.5252030576298776, nan)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'PT', 'PT_corr', and 'PT_qval' are columns in your merged_df
plt.figure(figsize=(10, 6))

# Calculate -log10(PT_qval)
merged_df['neg_log10_PT_qval'] = -np.log10(merged_df['PT_qval'])

# Create the scatter plot with color based on 'neg_log10_PT_qval'
plt.scatter(merged_df['PT_corr'],merged_df['PT'], c=merged_df['neg_log10_PT_qval'], cmap='viridis')

# Add labels and title
plt.xlabel('Ligand Correlation with PT Fate')
plt.ylabel('Gene Correlation with PT Fate')
plt.title('Scatter Plot of PT vs PT_corr with -log10(PT_qval) as Color')

# Add a colorbar
plt.colorbar(label='-log10(PT_qval)')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'PT', 'PT_corr', and 'PT_qval' are columns in your merged_df
plt.figure(figsize=(10, 6))

# Calculate -log10(PT_qval)
merged_df['neg_log10_LOH_qval'] = -np.log10(merged_df['LOH_qval'])

# Create the scatter plot with color based on 'neg_log10_PT_qval'
plt.scatter(merged_df['LOH'], merged_df['LOH_corr'], c=merged_df['neg_log10_LOH_qval'], cmap='viridis')

# Add labels and title
plt.xlabel('Ligand Correlation with LOH Fate')
plt.ylabel('Gene Correlation with LOH Fate')
plt.title('Scatter Plot of PT vs PT_corr with -log10(PT_qval) as Color')

# Add a colorbar
plt.colorbar(label='-log10(LOH_qval)')

# Show the plot
plt.show()

# %%
# prompt: can you plot a histogram merged df using the PT_cor, but coloring if there is a value for PT

import matplotlib.pyplot as plt

# Create a histogram of PT_cor, coloring based on whether PT is present
plt.hist(merged_df['PT_corr'], bins=50, color='gray', label='No PT Value')
plt.hist(merged_df[merged_df['PT'].notna()]['PT_corr'], bins=50, color='blue', label='PT Value Present')

# Customize the plot (optional)
plt.title("PT_cor Histogram with PT Value Presence", fontsize=20)
plt.xlabel("PT_cor")
plt.ylabel("Frequency")
plt.legend()

# Show the plot
plt.show()

# %%
# prompt: can you plot a histogram merged df using the PT_corr, but coloring if there is a value for PT. and add a log axis

import matplotlib.pyplot as plt

# Create a histogram of PT_corr, coloring based on whether PT is present
plt.hist(merged_df['PT_corr'], bins=50, color='gray', label='Not a ligand', alpha=0.5)
plt.hist(merged_df[merged_df['PT'].notna()]['PT_corr'], bins=50, color='blue', label='Ligand', alpha=0.5)

# Customize the plot (optional)
plt.title("", fontsize=20)
plt.xlabel("Gene Correlation")
plt.ylabel("Frequency")
plt.legend()

# Add a log scale to the y-axis
plt.yscale('log')

# Show the plot
plt.show()

# %%
# prompt: can you make a histogram of values where PT and PT_corr are both not NaN

import matplotlib.pyplot as plt
# Create a histogram of PT_corr, coloring based on whether PT is present
plt.hist(merged_df[(merged_df['PT'].notna()) & (merged_df['PT_corr'].notna())]['PT'], bins=50, color='blue', label='PT and PT_corr Present')

# Customize the plot (optional)
plt.title("PT_corr Histogram with PT and PT_corr Present", fontsize=20)
plt.xlabel("PT")
plt.ylabel("Frequency")
plt.legend()

# Show the plot
plt.show()

# %%
merged_df[(merged_df['PT'].notna()) & (merged_df['PT_corr'].notna())]['PT_corr']
# Out:
# 0      0.348859
# 3     -0.060311
# 5      0.014522
# 6      0.002819
# 8      0.004050
#          ...
# 869   -0.023626
# 870   -0.012807
# 872   -0.008691
# 876    0.038077
# 877   -0.012360
# Name: PT_corr, Length: 316, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['DCT_corr'], merged_df['DCT'])
plt.xlabel('Gene correlation')
plt.ylabel('Ligand correlation')
plt.title('Genetic Correlation')
plt.tight_layout()
plt.show()

# %%
correlation = df2["DCT_corr"].corr(df2["LOH_corr"])
print(f"The correlation between DCT and LOH is: {correlation}")
# Out:
# The correlation between DCT and LOH is: 0.7123177203592608
